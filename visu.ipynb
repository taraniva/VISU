# %%
import visu_func

# %%
#Set axis limits
ax_max = 0.4
ax_min = -ax_max
ay_max = ax_max
ay_min = -ay_max

# %%
#Axis - one quadrant
ax_max = 1.0
ax_min = -0.1
ay_max = 1.0
ay_min = -0.1

# %% [markdown]
# # Draw routine parameters:
# 1. Node coordinates file
# * Cell attribute file
# * Connectivity file
# * Cell-centered variables file
# * Variable to plot
# * Span in x-direction
# * Span in y-direction

# %%
# Sedov
visu_func.draw(r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/mesh_005.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/input_cellsid.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/input_cnconn.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/vals_005.dat",
               'density',
               ax_min, ax_max,
               ay_min, ay_max,
                0.0, 6.0)

# %%
#Noh
visu_func.draw(r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/OUTPUT/mesh_001.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/OUTPUT/input_cellsid.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/OUTPUT/input_cnconn.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/OUTPUT/vals_001.dat",
               'density',
               ax_min, ax_max,
               ay_min, ay_max,
               0,        18  )    
               # 0.0,18.0)

# %%
#Triple point
visu_func.draw(r"/Users/Ivan/Documents/FJFI/Research/CCLUS/mesh_003.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CCLUS/input_cellsid.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CCLUS/input_cnconn.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CCLUS/vals_003.dat",
               'density',
               -0.0, 7.0,
               -0.0, 3.0,
                0.0, 1.0)

# %%
#Taylor-Green
visu_func.draw(r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/mesh_004.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/input_cellsid.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/input_cnconn.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/vals_004.dat",
               'pressure',
                0.0, 1.0,
                0.0, 1.0,
                0.6, 1.2)

# %%
#Sod
visu_func.draw(r"/Users/Ivan/Documents/FJFI/Research/CCLUS/mesh_004.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CCLUS/input_cellsid.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CCLUS/input_cnconn.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CCLUS/vals_004.dat",
               'density',
               -0.0, 1.0,
               -0.0, 0.03,
                0.0, 1.0)

# %%
#Pst
visu_func.draw(r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/OUTPUT/mesh_001.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/OUTPUT/input_cellsid.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/OUTPUT/input_cnconn.dat",
               r"/Users/Ivan/Documents/FJFI/Research/CODE/CCLUS/OUTPUT/vals_001.dat",
               'density',
               -0.0, 8.0,
               -0.0, 3.0,
                0.0, 10.0)
