# %%
import visu_func

# %% [markdown]
# # Draw routine parameters:
# 1. Node coordinates file
# * Cell attribute file
# * Connectivity file
# * Cell-centered variables file
# * Variable to be plotted
# * Span in x-direction
# * Span in y-direction

# %%
visu_func.draw(r"/Users/Ivan/Documents/FJFI/BC_Arbeit/CCLuS/mesh_000.dat",
               r"/Users/Ivan/Documents/FJFI/BC_Arbeit/CCLuS/input_cellsid.dat",
               r"/Users/Ivan/Documents/FJFI/BC_Arbeit/CCLuS/input_cnconn.dat",
               r"/Users/Ivan/Documents/FJFI/BC_Arbeit/CCLuS/vals_000.dat",
               'density',
               -1.0, 1.0,
               -1.0, 1.0)
